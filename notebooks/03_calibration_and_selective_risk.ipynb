# %% [markdown]
# # Calibration and Selective Risk
#
# 状态：2026-04-29 创建中文模板。
#
# 目标：整理 3D perception 作品集里的 reliability diagram、ECE/Brier、risk-coverage curve、subgroup reliability analysis。

# %% [markdown]
# ## 当前已知结果
#
# - Selected VoxelNeXt epoch34 baseline: mAP 0.1397, AvgR 0.1800, internal ECE 0.0624, Brier 0.1665, FPS 15.75。
# - Diagnostic ECE 通过 global affine-logit calibration 从 0.1043 降到 0.0078。
# - Classwise affine-logit calibration 达到 0.0071 diagnostic ECE。

# %% [markdown]
# ## 后续要补的内容
#
# - 读取 saved detection outputs。
# - 计算 ECE 和 Brier score。
# - 画 reliability diagram。
# - 画 risk-coverage curve。
# - 按 class、distance、VRU、小目标做 subgroup analysis。
