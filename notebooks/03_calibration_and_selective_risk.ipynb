# %% [markdown]
# # Calibration and Selective Risk
#
# Status: placeholder created on 2026-04-29.
#
# Goal: collect reliability diagrams, ECE/Brier calculations, risk-coverage curves, and subgroup reliability analysis for the 3D perception portfolio.

# %% [markdown]
# ## Current Known Results
#
# - Selected VoxelNeXt epoch34 baseline: mAP 0.1397, AvgR 0.1800, internal ECE 0.0624, Brier 0.1665, FPS 15.75.
# - Diagnostic ECE improves from 0.1043 to 0.0078 with global affine-logit calibration.
# - Classwise affine-logit calibration reaches 0.0071 diagnostic ECE.
